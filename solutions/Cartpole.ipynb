# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../pendulum1-v0.csv')
df.head(5)
# Out:
#    1   61
# 0  1   68
# 1  1   61
# 2  1   60
# 3  1  151
# 4  1   65

# %%
# %matplotlib inline
plt.figure(figsize=(15,8))
plt.xlabel("Época de treinamento")
plt.ylabel("Recompensa total")
plt.plot(df['61'])
